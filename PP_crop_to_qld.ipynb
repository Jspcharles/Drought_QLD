# %% [markdown]
# Crop into QLD

# %%
import os
import json
import xarray as xr
import geopandas as gpd
import rioxarray
import rasterio.features
import numpy as np

# === Paths ===
shapefile_path = r"D:\Project Works\Drought_QLD\Data\QLD_BioRegion_Shape_Files\Biogeographic_Regions.shp"
input_nc_folder = r"D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain"
output_nc_folder = r"D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD"
os.makedirs(output_nc_folder, exist_ok=True)

# === Load shapefile and assign integer codes ===
qld_shape = gpd.read_file(shapefile_path).to_crs("EPSG:4326")
region_list = qld_shape["q_reg"].tolist()
region_code_map = {code: idx for idx, code in enumerate(region_list)}
reverse_map = {idx: code for code, idx in region_code_map.items()}  # for JSON output

# === Add integer codes to GeoDataFrame ===
qld_shape["region_id"] = qld_shape["q_reg"].map(region_code_map)

# === List .nc files ===
nc_files = [f for f in os.listdir(input_nc_folder) if f.endswith(".nc")]

# === Process each file ===
for nc_file in nc_files:
    nc_path = os.path.join(input_nc_folder, nc_file)
    print(f"\n📂 Processing: {nc_file}")

    try:
        ds = xr.open_dataset(nc_path)
        ds = ds.rio.write_crs("EPSG:4326", inplace=True)

        # === Clip dataset to Queensland bounding geometry ===
        clipped = ds.rio.clip(qld_shape.geometry, qld_shape.crs, drop=True)

        # === Prepare rasterization ===
        transform = clipped.rio.transform()
        out_shape = (clipped.sizes["lat"], clipped.sizes["lon"])

        shapes = [
            (geom, rid) for geom, rid in zip(qld_shape.geometry, qld_shape.region_id)
        ]
        region_raster = rasterio.features.rasterize(
            shapes=shapes,
            out_shape=out_shape,
            transform=transform,
            fill=-1,
            dtype=np.int16
        )

        # === Add region_code variable to dataset ===
        clipped["region_code"] = (("lat", "lon"), region_raster)

        # === Save output ===
        output_path = os.path.join(output_nc_folder, f"QLD_{nc_file}")
        clipped.to_netcdf(output_path)
        print(f"✅ Saved with region_code → {output_path}")

    except Exception as e:
        print(f"❌ Failed for {nc_file}: {e}")

# === Save region_code map as JSON ===
with open(os.path.join(output_nc_folder, "region_code_map.json"), "w") as f:
    json.dump(reverse_map, f, indent=2)
    print("✅ Saved region_code_map.json")
# Out:
# 📂 Processing: 2000.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2000.monthly_rain.nc
#
# 📂 Processing: 2001.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2001.monthly_rain.nc
#
# 📂 Processing: 2002.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2002.monthly_rain.nc
#
# 📂 Processing: 2003.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2003.monthly_rain.nc
#
# 📂 Processing: 2004.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2004.monthly_rain.nc
#
# 📂 Processing: 2005.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2005.monthly_rain.nc
#
# 📂 Processing: 2006.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2006.monthly_rain.nc
#
# 📂 Processing: 2007.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2007.monthly_rain.nc
#
# 📂 Processing: 2008.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2008.monthly_rain.nc
#
# 📂 Processing: 2009.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2009.monthly_rain.nc
#
# 📂 Processing: 2010.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2010.monthly_rain.nc
#
# 📂 Processing: 2011.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2011.monthly_rain.nc
#
# 📂 Processing: 2012.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2012.monthly_rain.nc
#
# 📂 Processing: 2013.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2013.monthly_rain.nc
#
# 📂 Processing: 2014.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2014.monthly_rain.nc
#
# 📂 Processing: 2015.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2015.monthly_rain.nc
#
# 📂 Processing: 2016.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2016.monthly_rain.nc
#
# 📂 Processing: 2017.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2017.monthly_rain.nc
#
# 📂 Processing: 2018.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2018.monthly_rain.nc
#
# 📂 Processing: 2019.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2019.monthly_rain.nc
#
# 📂 Processing: 2020.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2020.monthly_rain.nc
#
# 📂 Processing: 2021.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2021.monthly_rain.nc
#
# 📂 Processing: 2022.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2022.monthly_rain.nc
#
# 📂 Processing: 2023.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2023.monthly_rain.nc
#
# 📂 Processing: 2024.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2024.monthly_rain.nc
#
# 📂 Processing: 2025.monthly_rain.nc
# ✅ Saved with region_code → D:\Project Works\Drought_QLD\Data\SPI\Monthly Rain QLD\QLD_2025.monthly_rain.nc
# ✅ Saved region_code_map.json
